# %% [markdown]
# # Test avec **th** et **ch**

# %%
# !python3 /content/new.py --input /content/corpus.txt --output /content/data.csv
# Out:
# Wrote analysis to: /content/data.csv

# %%
import polars as pl
import numpy as np

# Read the CSV file
df = pl.read_csv("/content/data_2.csv")

# Extract columns
x1 = df["th_count"].to_numpy()
x2 = df["ch_count"].to_numpy()

# Calculate and print correlation
correlation = np.corrcoef(x1, x2)[0, 1]
print(correlation)
# Out:
# -0.43743200597386817
